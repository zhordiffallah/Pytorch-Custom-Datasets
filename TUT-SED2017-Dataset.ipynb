# %% [markdown]
# ## 🌏 **Building a Custom DataLoader in PyTorch for the TUT Sound Event Detection 2017 Dataset (TUT SED2017)**
#
# ### **Overview**
# This notebook guides you through the process of creating a custom DataLoader in PyTorch specifically for the **TUT Sound Event Detection (SED) 2017** dataset. The goal is to efficiently load, process, and prepare this dataset for machine learning tasks, particularly for training and evaluating models that can classify environmental sounds based on audio data.
#
# ### **Objectives**
# 1. **Data Collection:**
#    - Retrieve and organize sound event audio files from the TUT dataset.
#    - Extract sound event labels for each audio file from the annotations provided.
#
# 2. **Custom DataLoader Creation:**
#    - Implement a custom PyTorch `Dataset` class that handles the loading and preprocessing of the dataset.
#    - Prepare the data for feeding into a deep learning model, ensuring that all necessary transformations are applied.
#
# ### **Structure**
# The notebook is structured as follows:
# 1. **Data Preparation:** Gathering and merging all relevant data sources.
# 2. **DataLoader Implementation:** Writing the custom PyTorch `Dataset` class.
# 3. **DataLoader Usage:** Demonstrating how to use the custom DataLoader in a PyTorch training loop.

# %%
# Import the drive module from google.colab to access Google Drive
# Mount the Google Drive to the Colab environment to access files and to download the dataset in your drive
# '/content/drive' is the directory where Google Drive will be mounted.
# After running this, you'll be prompted to authorize Colab to access your Drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### 📦 **Importing Necessary Libraries**
#
# Here, we import essential libraries that will help us manipulate data, manage files, handle audio, and create custom datasets:
#
# - **pandas**: For reading, processing, and analyzing data from files.
# - **os**: To interact with the operating system, such as navigating directories and working with file paths.
# - **glob**: Helps find pathnames that match specific patterns, which is useful for locating dataset files.
# - **torch**: The core PyTorch library for tensor operations and deep learning models.
# - **torchaudio**: A specialized PyTorch library for audio processing, essential for handling the TUT-SED 2017 dataset.
# - **torch.utils.data.Dataset and DataLoader**: These utilities help us create and load custom datasets for model training.

# %%
import pandas as pd
import os
import glob
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# ### 📦 **Downloading and Extracting the TUT-SED 2017 Dataset**
# The **TUT-SED 2017** dataset is a comprehensive sound event detection (SED) dataset created for the **TUT Sound Events 2017** evaluation task. It contains environmental audio recordings that are annotated for sound events within the audio clips. The dataset is designed for training and testing algorithms to detect various sound events in realistic acoustic environments.
#
# #### Key Features of the Dataset:
# - **Audio Data**: The dataset consists of real-world audio recordings collected from an outdoor environment.
# - **Duration**: Each audio clip is approximately 3 to 5 minutes long, recorded with a sampling rate of 44.1 kHz.
# - **Annotations**: The dataset includes detailed annotations of sound event occurrences, specifying the type of sound and its temporal location within the audio clip.
# - **Classes**: Common sound event categories include: brakes squeaking, car, children, large vehicle, people speaking, and people walking
# - **Task**: The task associated with this dataset is to detect and label the occurrence of different sound events in a continuous audio stream.
#
# #### Applications:
# The TUT-SED 2017 dataset is primarily used for research in **sound event detection** and can be applied in various fields like:
# - **Acoustic scene analysis**
# - **Urban sound monitoring**
# - **Audio-based surveillance**
#
#
# More information and access to the dataset can be found on the official [Zenodo page](https://zenodo.org/record/400516).
# To work with the **TUT-SED 2017** dataset, we first need to download it from Zenodo. Here's what's happening:
#
# - **wget**: This command fetches the dataset as a `.zip` file from the provided URL. We rename the file to `tut-sed-2017-dataset.zip` for clarity.
# - **unzip**: We extract the contents of the `.zip` file into a directory called `/content/dataset`.
#
# This step ensures that all dataset files are available for use in the subsequent parts of our project.

# %%
# Use wget to download the TUT-SED 2017 dataset from Zenodo using its URL
# The '-O' option renames the downloaded file as 'tut-sed-2017-dataset.zip'
# !wget 'https://zenodo.org/api/records/400516/files-archive' -O tut-sed-2017-dataset.zip

# Unzipping the downloaded dataset file into a specified directory (/content/dataset)
# The '-d' option specifies the extraction directory
# !unzip tut-sed-2017-dataset.zip -d /content/dataset
# Out:
# --2024-09-18 14:04:40--  https://zenodo.org/api/records/400516/files-archive
# Resolving zenodo.org (zenodo.org)... 188.185.79.172, 188.184.103.159, 188.184.98.238, ...
# Connecting to zenodo.org (zenodo.org)|188.185.79.172|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘tut-sed-2017-dataset.zip’
#
# tut-sed-2017-datase     [                 <=>]   1.19G  25.5MB/s    in 52s
#
# 2024-09-18 14:05:32 (23.3 MB/s) - ‘tut-sed-2017-dataset.zip’ saved [1276013274]
#
# Archive:  tut-sed-2017-dataset.zip
#  extracting: /content/dataset/TUT-sound-events-2017-development.meta.zip
#  extracting: /content/dataset/TUT-sound-events-2017-development.audio.2.zip
#  extracting: /content/dataset/TUT-sound-events-2017-development.doc.zip
#  extracting: /content/dataset/TUT-sound-events-2017-development.audio.1.zip

# %%
# Once the dataset is downloaded, it comes in multiple `.zip` files, each containing specific parts of the dataset, such as audio, metadata, and documentation.
# We will extract these files into corresponding directories for easy access:
# - **Metadata**: Unzips the **TUT-sound-events-2017-development.meta.zip** file, which contains the annotations for the dataset, into the `/content/dataset/meta` directory.
# - **Audio Part 1**: Unzips the first set of audio files, **TUT-sound-events-2017-development.audio.1.zip**, into `/content/dataset/audio1`.
# - **Audio Part 2**: Unzips the second set of audio files, **TUT-sound-events-2017-development.audio.2.zip**, into `/content/dataset/audio2`.
# - **Documentation**: Unzips the **TUT-sound-events-2017-development.doc.zip**, which contains the documentation for the dataset, into `/content/dataset/doc`.
# !unzip /content/dataset/TUT-sound-events-2017-development.meta.zip -d /content/dataset/meta
# !unzip /content/dataset/TUT-sound-events-2017-development.audio.1.zip -d /content/dataset/audio1
# !unzip /content/dataset/TUT-sound-events-2017-development.audio.2.zip -d /content/dataset/audio2
# !unzip /content/dataset/TUT-sound-events-2017-development.doc.zip -d /content/dataset/doc
# Out:
# Archive:  /content/dataset/TUT-sound-events-2017-development.meta.zip
#    creating: /content/dataset/meta/TUT-sound-events-2017-development/
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta.txt
#    creating: /content/dataset/meta/TUT-sound-events-2017-development/meta/
#    creating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a008.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b008.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b003.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b005.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b093.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a129.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a124.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b100.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a128.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a010.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a127.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a131.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b099.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a012.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a013.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a001.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b006.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b009.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b007.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b098.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b091.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b094.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/b095.ann
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/meta/street/a003.ann
#    creating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold2_train.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold3_test.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold1_evaluate.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold4_evaluate.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold1_test.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold1_train.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold4_train.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold4_test.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold3_train.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold2_evaluate.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold3_evaluate.txt
#   inflating: /content/dataset/meta/TUT-sound-events-2017-development/evaluation_setup/street_fold2_test.txt
# Archive:  /content/dataset/TUT-sound-events-2017-development.audio.1.zip
#    creating: /content/dataset/audio1/TUT-sound-events-2017-development/
#    creating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/
#    creating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a012.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b006.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a001.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b100.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a124.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a008.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b009.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b008.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a129.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a013.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b005.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a003.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b091.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b099.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b094.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a127.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b003.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/a010.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b098.wav
#   inflating: /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/b095.wav
# Archive:  /content/dataset/TUT-sound-events-2017-development.audio.2.zip
#   inflating: /content/dataset/audio2/TUT-sound-events-2017-development/audio/street/a128.wav
#   inflating: /content/dataset/audio2/TUT-sound-events-2017-development/audio/street/a131.wav
#   inflating: /content/dataset/audio2/TUT-sound-events-2017-development/audio/street/b093.wav
#   inflating: /content/dataset/audio2/TUT-sound-events-2017-development/audio/street/b007.wav
# Archive:  /content/dataset/TUT-sound-events-2017-development.doc.zip
#    creating: /content/dataset/doc/TUT-sound-events-2017-development/
#   inflating: /content/dataset/doc/TUT-sound-events-2017-development/EULA.pdf
#   inflating: /content/dataset/doc/TUT-sound-events-2017-development/README.html
#   inflating: /content/dataset/doc/TUT-sound-events-2017-development/README.md

# %%
# Check the contents of the audio1 folder
# !ls /content/dataset/audio1/TUT-sound-events-2017-development/audio/street
# Out:
# a001.wav  a008.wav  a012.wav  a124.wav	a129.wav  b005.wav  b008.wav  b091.wav	b095.wav  b099.wav
# a003.wav  a010.wav  a013.wav  a127.wav	b003.wav  b006.wav  b009.wav  b094.wav	b098.wav  b100.wav

# %%
# Check the contents of the audio2 folder
# !ls /content/dataset/audio2/TUT-sound-events-2017-development/audio/street
# Out:
# a128.wav  a131.wav  b007.wav  b093.wav

# %%
# Check the contents of the meta folder
# !ls /content/dataset/meta/TUT-sound-events-2017-development
# Out:
# evaluation_setup  meta	meta.txt

# %%
# Display the contents of meta.txt
# !cat /content/dataset/meta/TUT-sound-events-2017-development/meta.txt
# Out:
# audio/street/a001.wav	street	1.589213	2.38382	people walking	mixture	a001
# audio/street/a001.wav	street	3.500767	4.156693	people walking	mixture	a001
# audio/street/a001.wav	street	4.156693	14.00307	car	mixture	a001
# audio/street/a001.wav	street	8.508289	11.844138	car	mixture	a001
# audio/street/a001.wav	street	14.381632	20.000102	car	mixture	a001
# audio/street/a001.wav	street	21.304456	30.030138	car	mixture	a001
# audio/street/a001.wav	street	24.842705	28.152317	large vehicle	mixture	a001
# audio/street/a001.wav	street	28.152317	29.252398	brakes squeaking	mixture	a001
# audio/street/a001.wav	street	29.252398	58.740928	large vehicle	mixture	a001
# audio/street/a001.wav	street	35.862251	43.373534	car	mixture	a001
# audio/street/a001.wav	street	43.373534	49.445529	car	mixture	a001
# audio/street/a001.wav	street	58.740928	69.370667	large vehicle	mixture	a001
# audio/street/a001.wav	street	70.465126	73.744753	car	mixture	a001
# audio/street/a001.wav	street	72.339198	77.20429	car	mixture	a001
# audio/street/a001.wav	street	76.627076	77.721534	people walking	mixture	a001
# audio/street/a001.wav	street	84.040907	94.610676	people speaking	mixture	a001
# audio/street/a001.wav	street	89.153377	100.03799	people walking	mixture	a001
# audio/street/a001.wav	street	102.976535	106.844621	people speaking	mixture	a001
# audio/street/a001.wav	street	112.446534	115.485629	people walking	mixture	a001
# audio/street/a001.wav	street	116.897146	133.958702	car	mixture	a001
# audio/street/a001.wav	street	118.345954	119.895297	people walking	mixture	a001
# audio/street/a001.wav	street	137.077158	143.928767	car	mixture	a001
# audio/street/a001.wav	street	143.928767	153.014271	car	mixture	a001
# audio/street/a001.wav	street	159.386117	168.006851	car	mixture	a001
# audio/street/a001.wav	street	168.006851	176.042874	car	mixture	a001
# audio/street/a003.wav	street	74.929903	80.2038	car	mixture	a003
# audio/street/a003.wav	street	80.2038	103.246672	car	mixture	a003
# audio/street/a003.wav	street	145.518983	151.157996	car	mixture	a003
# audio/street/a003.wav	street	152.33448	157.52724	car	mixture	a003
# audio/street/a003.wav	street	211.320987	216.148631	people speaking	mixture	a003
# audio/street/a003.wav	street	222.071623	227.994615	car	mixture	a003
# audio/street/a003.wav	street	232.943964	237.73104	car	mixture	a003
# audio/street/a008.wav	street	0.184586	0.469855	people speaking	mixture	a008
# audio/street/a008.wav	street	61.735534	64.957394	people walking	mixture	a008
# audio/street/a008.wav	street	63.044415	63.514269	people speaking	mixture	a008
# audio/street/a008.wav	street	86.201532	109.325089	people speaking	mixture	a008
# audio/street/a008.wav	street	148.70897	152.182538	car	mixture	a008
# audio/street/a008.wav	street	159.599528	163.22412	car	mixture	a008
# audio/street/a008.wav	street	187.975388	189.401732	people walking	mixture	a008
# audio/street/a010.wav	street	0.138062	5.332654	car	mixture	a010
# audio/street/a010.wav	street	128.544568	134.481244	car	mixture	a010
# audio/street/a010.wav	street	181.431033	193.149065	people walking	mixture	a010
# audio/street/a010.wav	street	194.909358	198.516234	people walking	mixture	a010
# audio/street/a012.wav	street	0.0	202.528774	children	mixture	a012
# audio/street/a012.wav	street	4.096064	5.100089	children	mixture	a012
# audio/street/a012.wav	street	6.859353	7.525741	children	mixture	a012
# audio/street/a012.wav	street	21.884179	22.990383	people speaking	mixture	a012
# audio/street/a012.wav	street	23.097005	27.130873	children	mixture	a012
# audio/street/a012.wav	street	26.579992	31.604557	people speaking	mixture	a012
# audio/street/a012.wav	street	31.862227	34.727695	children	mixture	a012
# audio/street/a012.wav	street	39.139183	57.527046	people speaking	mixture	a012
# audio/street/a012.wav	street	41.156117	43.537343	children	mixture	a012
# audio/street/a012.wav	street	44.199288	45.780849	children	mixture	a012
# audio/street/a012.wav	street	48.721841	50.378926	children	mixture	a012
# audio/street/a012.wav	street	52.924527	55.443474	children	mixture	a012
# audio/street/a012.wav	street	57.527046	195.202787	people speaking	mixture	a012
# audio/street/a012.wav	street	63.937698	65.33267	children	mixture	a012
# audio/street/a012.wav	street	66.247843	68.30476	children	mixture	a012
# audio/street/a012.wav	street	89.473683	91.17075	children	mixture	a012
# audio/street/a012.wav	street	92.210315	93.152144	children	mixture	a012
# audio/street/a012.wav	street	93.47201	100.286937	children	mixture	a012
# audio/street/a012.wav	street	120.660636	121.638005	children	mixture	a012
# audio/street/a012.wav	street	134.166098	134.699208	children	mixture	a012
# audio/street/a012.wav	street	164.580042	166.499239	children	mixture	a012
# audio/street/a012.wav	street	191.537654	192.186271	children	mixture	a012
# audio/street/a012.wav	street	195.202787	208.62384	large vehicle	mixture	a012
# audio/street/a012.wav	street	206.518054	212.888722	children	mixture	a012
# audio/street/a012.wav	street	212.408923	213.732814	people speaking	mixture	a012
# audio/street/a013.wav	street	5.75604	8.771984	people walking	mixture	a013
# audio/street/a013.wav	street	107.764837	109.14408	people walking	mixture	a013
# audio/street/a124.wav	street	0.0	4.037666	people speaking	mixture	a124
# audio/street/a124.wav	street	0.0	21.850174	large vehicle	mixture	a124
# audio/street/a124.wav	street	1.772634	4.222315	people walking	mixture	a124
# audio/street/a124.wav	street	6.684307	15.732125	car	mixture	a124
# audio/street/a124.wav	street	21.850174	31.55042	large vehicle	mixture	a124
# audio/street/a124.wav	street	28.202112	32.227468	people walking	mixture	a124
# audio/street/a124.wav	street	44.118886	53.314424	car	mixture	a124
# audio/street/a124.wav	street	44.402015	46.162339	people walking	mixture	a124
# audio/street/a124.wav	street	50.039976	62.066804	car	mixture	a124
# audio/street/a124.wav	street	74.278281	92.583188	large vehicle	mixture	a124
# audio/street/a124.wav	street	74.703882	78.445914	people walking	mixture	a124
# audio/street/a124.wav	street	93.395645	98.578137	people walking	mixture	a124
# audio/street/a124.wav	street	96.214625	109.05391	car	mixture	a124
# audio/street/a124.wav	street	109.12777	116.218305	car	mixture	a124
# audio/street/a124.wav	street	116.304475	121.880886	car	mixture	a124
# audio/street/a124.wav	street	121.733166	127.949695	large vehicle	mixture	a124
# audio/street/a124.wav	street	130.251657	132.787508	brakes squeaking	mixture	a124
# audio/street/a124.wav	street	131.408792	187.480647	large vehicle	mixture	a124
# audio/street/a124.wav	street	159.167746	169.50811	car	mixture	a124
# audio/street/a124.wav	street	166.824539	169.865099	people walking	mixture	a124
# audio/street/a124.wav	street	184.932486	188.219245	car	mixture	a124
# audio/street/a124.wav	street	187.480647	194.214194	large vehicle	mixture	a124
# audio/street/a124.wav	street	193.204777	197.414783	car	mixture	a124
# audio/street/a124.wav	street	204.505318	219.277267	car	mixture	a124
# audio/street/a124.wav	street	209.958629	212.54372	people speaking	mixture	a124
# audio/street/a124.wav	street	217.123024	230.060789	car	mixture	a124
# audio/street/a124.wav	street	238.136121	244.574228	car	mixture	a124
# audio/street/a124.wav	street	244.574228	256.822636	car	mixture	a124
# audio/street/a124.wav	street	255.197722	269.391102	large vehicle	mixture	a124
# audio/street/a124.wav	street	269.612681	276.900176	large vehicle	mixture	a124
# audio/street/a124.wav	street	276.247748	289.936421	large vehicle	mixture	a124
# audio/street/a124.wav	street	285.184777	298.417981	car	mixture	a124
# audio/street/a124.wav	street	293.793001	298.922689	people speaking	mixture	a124
# audio/street/a124.wav	street	299.882866	300.953832	people speaking	mixture	a124
# audio/street/a127.wav	street	0.0	65.024478	people walking	mixture	a127
# audio/street/a127.wav	street	0.295063	51.291761	people speaking	mixture	a127
# audio/street/a127.wav	street	7.364277	20.150335	car	mixture	a127
# audio/street/a127.wav	street	59.23387	68.688176	large vehicle	mixture	a127
# audio/street/a127.wav	street	67.421864	68.061167	people speaking	mixture	a127
# audio/street/a127.wav	street	77.331059	78.265424	people speaking	mixture	a127
# audio/street/a127.wav	street	78.830962	90.363002	people walking	mixture	a127
# audio/street/a127.wav	street	84.916633	92.182556	car	mixture	a127
# audio/street/a127.wav	street	91.358839	113.045959	people walking	mixture	a127
# audio/street/a127.wav	street	92.502207	100.038605	large vehicle	mixture	a127
# audio/street/a127.wav	street	98.73541	100.960676	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	99.891073	185.434715	large vehicle	mixture	a127
# audio/street/a127.wav	street	99.891073	103.554771	people speaking	mixture	a127
# audio/street/a127.wav	street	108.460191	121.541311	large vehicle	mixture	a127
# audio/street/a127.wav	street	115.492522	116.267062	people speaking	mixture	a127
# audio/street/a127.wav	street	115.553994	137.31488	people walking	mixture	a127
# audio/street/a127.wav	street	118.627565	121.369191	people speaking	mixture	a127
# audio/street/a127.wav	street	121.897845	126.250022	large vehicle	mixture	a127
# audio/street/a127.wav	street	125.635308	130.77432	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	131.450505	133.208588	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	134.21672	136.11004	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	136.675577	143.609554	large vehicle	mixture	a127
# audio/street/a127.wav	street	143.400551	166.821166	people walking	mixture	a127
# audio/street/a127.wav	street	152.80568	163.292706	car	mixture	a127
# audio/street/a127.wav	street	163.636946	165.272086	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	166.907226	175.722229	people walking	mixture	a127
# audio/street/a127.wav	street	173.792026	174.578861	people speaking	mixture	a127
# audio/street/a127.wav	street	178.513032	180.590766	people walking	mixture	a127
# audio/street/a127.wav	street	179.545752	183.049624	children	mixture	a127
# audio/street/a127.wav	street	182.779149	192.454752	large vehicle	mixture	a127
# audio/street/a127.wav	street	191.803155	207.109541	people walking	mixture	a127
# audio/street/a127.wav	street	200.126387	213.883693	large vehicle	mixture	a127
# audio/street/a127.wav	street	200.446038	201.773821	people speaking	mixture	a127
# audio/street/a127.wav	street	213.883693	248.393753	large vehicle	mixture	a127
# audio/street/a127.wav	street	215.678658	300.570703	people walking	mixture	a127
# audio/street/a127.wav	street	222.956876	227.35823	people speaking	mixture	a127
# audio/street/a127.wav	street	224.997727	240.156582	large vehicle	mixture	a127
# audio/street/a127.wav	street	227.653293	227.997533	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	248.393753	265.691814	large vehicle	mixture	a127
# audio/street/a127.wav	street	259.040605	259.716791	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	261.118339	263.122308	people speaking	mixture	a127
# audio/street/a127.wav	street	267.056479	268.310497	large vehicle	mixture	a127
# audio/street/a127.wav	street	270.990651	271.851251	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	274.568288	275.551831	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	281.51456	282.03092	brakes squeaking	mixture	a127
# audio/street/a127.wav	street	284.600425	299.033917	large vehicle	mixture	a127
# audio/street/a127.wav	street	297.558603	300.570703	car	mixture	a127
# audio/street/a128.wav	street	0.0	4.359811	large vehicle	mixture	a128
# audio/street/a128.wav	street	2.258816	9.508729	people speaking	mixture	a128
# audio/street/a128.wav	street	4.320356	15.939944	large vehicle	mixture	a128
# audio/street/a128.wav	street	11.116533	32.264578	people speaking	mixture	a128
# audio/street/a128.wav	street	15.348115	25.093576	large vehicle	mixture	a128
# audio/street/a128.wav	street	20.043296	20.526624	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	22.065381	29.739438	people walking	mixture	a128
# audio/street/a128.wav	street	25.073848	36.141062	large vehicle	mixture	a128
# audio/street/a128.wav	street	34.493803	50.009602	people speaking	mixture	a128
# audio/street/a128.wav	street	36.249564	49.516411	people walking	mixture	a128
# audio/street/a128.wav	street	38.607018	39.228439	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	41.773307	59.666289	large vehicle	mixture	a128
# audio/street/a128.wav	street	46.310667	47.267458	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	50.216743	86.150664	people walking	mixture	a128
# audio/street/a128.wav	street	56.707141	62.477479	people speaking	mixture	a128
# audio/street/a128.wav	street	57.782298	58.245898	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	63.158083	67.133206	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	63.35536	88.034655	people speaking	mixture	a128
# audio/street/a128.wav	street	69.066516	69.609026	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	70.437588	77.085807	large vehicle	mixture	a128
# audio/street/a128.wav	street	75.369501	76.533433	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	82.195269	92.364875	large vehicle	mixture	a128
# audio/street/a128.wav	street	87.94588	109.301065	people walking	mixture	a128
# audio/street/a128.wav	street	91.131896	94.663146	people speaking	mixture	a128
# audio/street/a128.wav	street	94.515189	95.925716	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	95.185929	98.825681	car	mixture	a128
# audio/street/a128.wav	street	96.73455	98.342354	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	96.823324	102.692301	people speaking	mixture	a128
# audio/street/a128.wav	street	99.516149	103.086854	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	103.313722	110.849686	car	mixture	a128
# audio/street/a128.wav	street	109.172836	109.656163	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	109.902759	113.138094	people speaking	mixture	a128
# audio/street/a128.wav	street	110.889142	114.380936	people walking	mixture	a128
# audio/street/a128.wav	street	112.270077	118.030552	car	mixture	a128
# audio/street/a128.wav	street	115.120723	119.894815	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	117.399267	134.513007	people speaking	mixture	a128
# audio/street/a128.wav	street	121.344798	124.451903	people walking	mixture	a128
# audio/street/a128.wav	street	125.527061	130.528021	people walking	mixture	a128
# audio/street/a128.wav	street	126.967179	128.900489	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	130.616795	131.208625	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	131.129714	163.009603	people walking	mixture	a128
# audio/street/a128.wav	street	131.760999	146.09314	car	mixture	a128
# audio/street/a128.wav	street	139.740835	143.341132	people speaking	mixture	a128
# audio/street/a128.wav	street	145.29417	163.512658	people speaking	mixture	a128
# audio/street/a128.wav	street	148.450594	150.798185	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	159.261348	171.048622	large vehicle	mixture	a128
# audio/street/a128.wav	street	163.74939	164.114351	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	165.830657	166.461942	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	167.556827	168.267022	people walking	mixture	a128
# audio/street/a128.wav	street	167.793559	169.598639	people speaking	mixture	a128
# audio/street/a128.wav	street	170.003056	173.011523	people walking	mixture	a128
# audio/street/a128.wav	street	175.280203	196.398657	people speaking	mixture	a128
# audio/street/a128.wav	street	175.802986	177.87439	people walking	mixture	a128
# audio/street/a128.wav	street	177.351607	195.057176	large vehicle	mixture	a128
# audio/street/a128.wav	street	179.304645	187.284481	people walking	mixture	a128
# audio/street/a128.wav	street	194.81058	205.53256	people speaking	mixture	a128
# audio/street/a128.wav	street	194.948674	201.320706	people walking	mixture	a128
# audio/street/a128.wav	street	202.168995	241.150839	people walking	mixture	a128
# audio/street/a128.wav	street	207.584236	224.510563	people speaking	mixture	a128
# audio/street/a128.wav	street	217.990574	218.671178	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	224.125874	224.628929	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	228.465958	233.496509	people speaking	mixture	a128
# audio/street/a128.wav	street	238.684882	241.150839	brakes squeaking	mixture	a128
# audio/street/a128.wav	street	239.898133	241.150839	people speaking	mixture	a128
# audio/street/a129.wav	street	9.289038	10.607609	car	mixture	a129
# audio/street/a129.wav	street	13.323472	14.927405	people walking	mixture	a129
# audio/street/a129.wav	street	14.927405	17.87943	car	mixture	a129
# audio/street/a129.wav	street	18.213993	20.398491	people walking	mixture	a129
# audio/street/a129.wav	street	21.067617	24.088522	people walking	mixture	a129
# audio/street/a129.wav	street	24.491966	27.266869	car	mixture	a129
# audio/street/a129.wav	street	24.885569	25.475974	people walking	mixture	a129
# audio/street/a129.wav	street	27.44399	28.132796	people walking	mixture	a129
# audio/street/a129.wav	street	28.447679	32.14755	people walking	mixture	a129
# audio/street/a129.wav	street	28.59528	31.084821	car	mixture	a129
# audio/street/a129.wav	street	30.228734	32.413232	people speaking	mixture	a129
# audio/street/a129.wav	street	34.066366	35.6703	people walking	mixture	a129
# audio/street/a129.wav	street	35.512858	41.564509	people speaking	mixture	a129
# audio/street/a129.wav	street	35.562059	52.063877	people walking	mixture	a129
# audio/street/a129.wav	street	44.11309	47.330797	people speaking	mixture	a129
# audio/street/a129.wav	street	44.437813	55.084783	large vehicle	mixture	a129
# audio/street/a129.wav	street	55.694868	62.828928	car	mixture	a129
# audio/street/a129.wav	street	61.431636	62.051561	car	mixture	a129
# audio/street/a129.wav	street	62.710847	68.693617	car	mixture	a129
# audio/street/a129.wav	street	63.635814	64.609983	people walking	mixture	a129
# audio/street/a129.wav	street	63.862136	70.435311	people speaking	mixture	a129
# audio/street/a129.wav	street	68.240973	71.724362	people walking	mixture	a129
# audio/street/a129.wav	street	68.693617	73.357816	car	mixture	a129
# audio/street/a129.wav	street	73.357816	74.558306	car	mixture	a129
# audio/street/a129.wav	street	76.290161	77.913774	car	mixture	a129
# audio/street/a129.wav	street	78.012175	79.80307	car	mixture	a129
# audio/street/a129.wav	street	80.039232	80.757558	brakes squeaking	mixture	a129
# audio/street/a129.wav	street	80.757558	83.069978	car	mixture	a129
# audio/street/a129.wav	street	83.069978	86.208964	car	mixture	a129
# audio/street/a129.wav	street	86.208964	88.954347	car	mixture	a129
# audio/street/a129.wav	street	86.602567	88.09826	brakes squeaking	mixture	a129
# audio/street/a129.wav	street	87.999859	90.351639	brakes squeaking	mixture	a129
# audio/street/a129.wav	street	90.873163	93.146222	car	mixture	a129
# audio/street/a129.wav	street	98.164664	102.553341	large vehicle	mixture	a129
# audio/street/a129.wav	street	122.538549	128.895242	car	mixture	a129
# audio/street/a129.wav	street	134.208887	139.542212	car	mixture	a129
# audio/street/a129.wav	street	139.591412	144.629534	car	mixture	a129
# audio/street/a129.wav	street	141.598789	148.496687	people walking	mixture	a129
# audio/street/a129.wav	street	145.101858	151.104309	car	mixture	a129
# audio/street/a129.wav	street	149.874299	154.84354	car	mixture	a129
# audio/street/a129.wav	street	151.675034	158.956695	people walking	mixture	a129
# audio/street/a129.wav	street	159.261737	163.296171	car	mixture	a129
# audio/street/a129.wav	street	163.689775	167.232204	car	mixture	a129
# audio/street/a129.wav	street	198.720469	202.597461	car	mixture	a129
# audio/street/a129.wav	street	205.913569	209.790562	car	mixture	a129
# audio/street/a129.wav	street	210.80409	228.555599	large vehicle	mixture	a129
# audio/street/a129.wav	street	226.813905	231.379703	people walking	mixture	a129
# audio/street/a129.wav	street	229.549448	231.094341	children	mixture	a129
# audio/street/a129.wav	street	231.852027	233.583881	people speaking	mixture	a129
# audio/street/a129.wav	street	236.043902	240.57034	people walking	mixture	a129
# audio/street/a131.wav	street	0.0	25.786823	people walking	mixture	a131
# audio/street/a131.wav	street	9.997565	16.498445	people speaking	mixture	a131
# audio/street/a131.wav	street	15.966555	17.562225	children	mixture	a131
# audio/street/a131.wav	street	17.906969	21.915845	people speaking	mixture	a131
# audio/street/a131.wav	street	26.308863	29.7169	people walking	mixture	a131
# audio/street/a131.wav	street	29.382006	29.894197	children	mixture	a131
# audio/street/a131.wav	street	30.662483	34.297065	children	mixture	a131
# audio/street/a131.wav	street	31.489867	40.571399	people walking	mixture	a131
# audio/street/a131.wav	street	38.236993	44.32418	people speaking	mixture	a131
# audio/street/a131.wav	street	44.205982	51.780492	large vehicle	mixture	a131
# audio/street/a131.wav	street	62.339497	66.663567	car	mixture	a131
# audio/street/a131.wav	street	79.281183	81.349645	people walking	mixture	a131
# audio/street/a131.wav	street	84.038645	94.361254	people walking	mixture	a131
# audio/street/a131.wav	street	87.387583	92.499639	car	mixture	a131
# audio/street/a131.wav	street	91.780602	94.361254	people speaking	mixture	a131
# audio/street/a131.wav	street	98.626225	102.388856	people speaking	mixture	a131
# audio/street/a131.wav	street	98.980819	99.680156	brakes squeaking	mixture	a131
# audio/street/a131.wav	street	101.699368	107.983552	people walking	mixture	a131
# audio/street/a131.wav	street	108.269197	128.008232	car	mixture	a131
# audio/street/a131.wav	street	124.245601	125.811722	brakes squeaking	mixture	a131
# audio/street/a131.wav	street	126.057968	127.880184	brakes squeaking	mixture	a131
# audio/street/a131.wav	street	129.259159	130.569184	brakes squeaking	mixture	a131
# audio/street/a131.wav	street	130.293389	131.761012	people speaking	mixture	a131
# audio/street/a131.wav	street	131.534466	135.1001	people walking	mixture	a131
# audio/street/a131.wav	street	134.331815	139.030178	people speaking	mixture	a131
# audio/street/a131.wav	street	136.76472	140.320504	people walking	mixture	a131
# audio/street/a131.wav	street	138.724833	143.2262	people walking	mixture	a131
# audio/street/a131.wav	street	140.468251	145.511358	car	mixture	a131
# audio/street/a131.wav	street	146.348592	147.698017	people speaking	mixture	a131
# audio/street/a131.wav	street	148.269307	172.42106	people walking	mixture	a131
# audio/street/a131.wav	street	161.931004	163.21148	children	mixture	a131
# audio/street/a131.wav	street	165.447389	168.865276	people speaking	mixture	a131
# audio/street/a131.wav	street	170.076803	188.249717	people speaking	mixture	a131
# audio/street/a131.wav	street	172.42106	174.312225	children	mixture	a131
# audio/street/a131.wav	street	179.847823	204.038975	people walking	mixture	a131
# audio/street/a131.wav	street	193.637567	197.547945	people speaking	mixture	a131
# audio/street/a131.wav	street	204.393568	209.022983	people walking	mixture	a131
# audio/street/a131.wav	street	208.126649	208.678239	people speaking	mixture	a131
# audio/street/a131.wav	street	209.673071	212.96291	people speaking	mixture	a131
# audio/street/a131.wav	street	213.4751	215.68146	children	mixture	a131
# audio/street/a131.wav	street	216.341397	226.289713	children	mixture	a131
# audio/street/a131.wav	street	219.897182	231.490417	people walking	mixture	a131
# audio/street/a131.wav	street	231.057025	231.569216	brakes squeaking	mixture	a131
# audio/street/a131.wav	street	232.179904	234.366564	people speaking	mixture	a131
# audio/street/a131.wav	street	240.187806	240.808345	people speaking	mixture	a131
# audio/street/b003.wav	street	0.298388	13.49486	people walking	mixture	b003
# audio/street/b003.wav	street	4.822343	18.04769	car	mixture	b003
# audio/street/b003.wav	street	18.240199	32.033447	car	mixture	b003
# audio/street/b003.wav	street	27.856008	30.310494	people walking	mixture	b003
# audio/street/b003.wav	street	30.974649	35.498604	large vehicle	mixture	b003
# audio/street/b003.wav	street	37.750955	40.898473	people walking	mixture	b003
# audio/street/b003.wav	street	54.133445	54.518463	people walking	mixture	b003
# audio/street/b003.wav	street	75.81955	77.013104	people walking	mixture	b003
# audio/street/b003.wav	street	78.293287	87.013931	car	mixture	b003
# audio/street/b003.wav	street	84.222555	101.509836	people walking	mixture	b003
# audio/street/b003.wav	street	84.463191	95.012667	car	mixture	b003
# audio/street/b003.wav	street	101.240323	115.524469	car	mixture	b003
# audio/street/b003.wav	street	112.309573	146.489492	large vehicle	mixture	b003
# audio/street/b003.wav	street	140.194458	155.027253	car	mixture	b003
# audio/street/b003.wav	street	149.290494	235.32263	car	mixture	b003
# audio/street/b003.wav	street	152.592018	180.005256	car	mixture	b003
# audio/street/b003.wav	street	186.560178	201.999375	car	mixture	b003
# audio/street/b003.wav	street	202.413269	216.524156	car	mixture	b003
# audio/street/b003.wav	street	217.111308	229.489617	car	mixture	b003
# audio/street/b003.wav	street	221.80852	225.01379	people walking	mixture	b003
# audio/street/b005.wav	street	13.301361	14.206216	people speaking	mixture	b005
# audio/street/b005.wav	street	21.650701	34.993192	car	mixture	b005
# audio/street/b005.wav	street	35.272874	47.990193	car	mixture	b005
# audio/street/b005.wav	street	44.971269	54.990476	people walking	mixture	b005
# audio/street/b005.wav	street	54.159655	55.113865	children	mixture	b005
# audio/street/b005.wav	street	60.246858	62.031889	children	mixture	b005
# audio/street/b005.wav	street	63.923858	95.017949	car	mixture	b005
# audio/street/b005.wav	street	86.800225	94.022609	people walking	mixture	b005
# audio/street/b005.wav	street	95.453925	127.090929	people walking	mixture	b005
# audio/street/b005.wav	street	103.778586	104.864411	children	mixture	b005
# audio/street/b005.wav	street	104.864411	120.9955	car	mixture	b005
# audio/street/b005.wav	street	123.241184	124.014423	children	mixture	b005
# audio/street/b005.wav	street	126.325915	130.052271	children	mixture	b005
# audio/street/b005.wav	street	138.459192	165.045462	car	mixture	b005
# audio/street/b005.wav	street	145.878998	147.993068	children	mixture	b005
# audio/street/b005.wav	street	155.626749	157.83953	children	mixture	b005
# audio/street/b005.wav	street	158.629221	160.060536	people speaking	mixture	b005
# audio/street/b005.wav	street	179.662975	180.707671	children	mixture	b005
# audio/street/b005.wav	street	183.043841	185.54453	children	mixture	b005
# audio/street/b005.wav	street	188.982977	189.863153	children	mixture	b005
# audio/street/b005.wav	street	191.557699	192.536587	people speaking	mixture	b005
# audio/street/b005.wav	street	194.181777	195.259377	people speaking	mixture	b005
# audio/street/b006.wav	street	0.0	12.038328	car	mixture	b006
# audio/street/b006.wav	street	3.888325	4.252571	people speaking	mixture	b006
# audio/street/b006.wav	street	10.198886	22.993025	car	mixture	b006
# audio/street/b006.wav	street	21.572466	33.993253	car	mixture	b006
# audio/street/b006.wav	street	44.583703	66.001365	car	mixture	b006
# audio/street/b006.wav	street	61.457397	69.024606	car	mixture	b006
# audio/street/b006.wav	street	68.469131	71.510585	car	mixture	b006
# audio/street/b006.wav	street	70.95511	88.010926	car	mixture	b006
# audio/street/b006.wav	street	86.390031	93.520146	car	mixture	b006
# audio/street/b006.wav	street	94.212213	117.004903	large vehicle	mixture	b006
# audio/street/b006.wav	street	113.007304	129.999377	car	mixture	b006
# audio/street/b006.wav	street	116.249093	116.759037	car	mixture	b006
# audio/street/b006.wav	street	122.896581	135.007759	car	mixture	b006
# audio/street/b006.wav	street	133.341333	137.493737	car	mixture	b006
# audio/street/b006.wav	street	135.153457	142.019493	car	mixture	b006
# audio/street/b006.wav	street	139.688319	144.523684	car	mixture	b006
# audio/street/b006.wav	street	142.793516	147.492288	car	mixture	b006
# audio/street/b006.wav	street	145.252176	153.994078	car	mixture	b006
# audio/street/b006.wav	street	150.870669	164.994306	car	mixture	b006
# audio/street/b006.wav	street	164.620954	173.007717	car	mixture	b006
# audio/street/b006.wav	street	173.790845	183.989732	car	mixture	b006
# audio/street/b006.wav	street	176.631964	197.002418	people walking	mixture	b006
# audio/street/b006.wav	street	196.483368	208.029964	car	mixture	b006
# audio/street/b006.wav	street	205.425606	210.534155	car	mixture	b006
# audio/street/b006.wav	street	209.441417	213.02924	car	mixture	b006
# audio/street/b006.wav	street	211.144267	222.62712	car	mixture	b006
# audio/street/b007.wav	street	0.079906	0.461679	people walking	mixture	b007
# audio/street/b007.wav	street	1.704661	2.255124	people walking	mixture	b007
# audio/street/b007.wav	street	2.921007	10.059274	children	mixture	b007
# audio/street/b007.wav	street	5.060712	23.01292	car	mixture	b007
# audio/street/b007.wav	street	13.894761	36.51703	children	mixture	b007
# audio/street/b007.wav	street	14.542887	31.846969	people walking	mixture	b007
# audio/street/b007.wav	street	21.254989	30.515203	car	mixture	b007
# audio/street/b007.wav	street	28.490919	44.028191	car	mixture	b007
# audio/street/b007.wav	street	39.25159	46.549668	children	mixture	b007
# audio/street/b007.wav	street	47.597324	49.239836	children	mixture	b007
# audio/street/b007.wav	street	49.470676	51.645894	people walking	mixture	b007
# audio/street/b007.wav	street	53.927653	54.682321	people speaking	mixture	b007
# audio/street/b007.wav	street	53.927653	59.006122	children	mixture	b007
# audio/street/b007.wav	street	63.365436	67.520547	car	mixture	b007
# audio/street/b007.wav	street	88.083017	89.592352	people walking	mixture	b007
# audio/street/b007.wav	street	92.335791	96.996973	people walking	mixture	b007
# audio/street/b007.wav	street	97.494165	102.519363	car	mixture	b007
# audio/street/b007.wav	street	104.854393	109.266979	people walking	mixture	b007
# audio/street/b007.wav	street	112.063688	117.017858	car	mixture	b007
# audio/street/b007.wav	street	118.198691	118.527193	people walking	mixture	b007
# audio/street/b007.wav	street	124.422478	126.961712	people walking	mixture	b007
# audio/street/b007.wav	street	131.063552	143.528884	car	mixture	b007
# audio/street/b007.wav	street	140.492457	160.025028	car	mixture	b007
# audio/street/b007.wav	street	151.821348	152.283027	people walking	mixture	b007
# audio/street/b007.wav	street	160.406801	160.841845	people walking	mixture	b007
# audio/street/b007.wav	street	166.941334	167.376378	people walking	mixture	b007
# audio/street/b007.wav	street	167.909084	199.001386	car	mixture	b007
# audio/street/b007.wav	street	174.132872	174.514645	people walking	mixture	b007
# audio/street/b007.wav	street	182.301038	182.718325	people walking	mixture	b007
# audio/street/b007.wav	street	202.304166	217.060136	car	mixture	b007
# audio/street/b008.wav	street	4.197238	4.493309	people walking	mixture	b008
# audio/street/b008.wav	street	14.585837	16.344846	people walking	mixture	b008
# audio/street/b008.wav	street	26.724737	27.430082	people walking	mixture	b008
# audio/street/b008.wav	street	28.475038	33.011886	children	mixture	b008
# audio/street/b008.wav	street	33.908806	48.729759	large vehicle	mixture	b008
# audio/street/b008.wav	street	47.44098	52.509014	brakes squeaking	mixture	b008
# audio/street/b008.wav	street	48.729759	60.729331	large vehicle	mixture	b008
# audio/street/b008.wav	street	52.212944	52.596094	large vehicle	mixture	b008
# audio/street/b008.wav	street	60.729331	81.994176	large vehicle	mixture	b008
# audio/street/b008.wav	street	87.140582	89.030209	people walking	mixture	b008
# audio/street/b008.wav	street	103.807622	108.0484	people walking	mixture	b008
# audio/street/b008.wav	street	110.425674	111.279054	people walking	mixture	b008
# audio/street/b008.wav	street	113.011938	115.023478	children	mixture	b008
# audio/street/b008.wav	street	118.654698	152.833451	people walking	mixture	b008
# audio/street/b008.wav	street	119.804149	149.001948	car	mixture	b008
# audio/street/b008.wav	street	154.522796	155.515504	children	mixture	b008
# audio/street/b008.wav	street	157.300636	158.014689	people speaking	mixture	b008
# audio/street/b008.wav	street	165.285838	166.052139	children	mixture	b008
# audio/street/b008.wav	street	169.395996	169.901058	children	mixture	b008
# audio/street/b008.wav	street	182.997834	183.650931	children	mixture	b008
# audio/street/b008.wav	street	184.948417	187.012204	car	mixture	b008
# audio/street/b008.wav	street	190.460558	192.080239	children	mixture	b008
# audio/street/b008.wav	street	193.14261	210.802358	children	mixture	b008
# audio/street/b008.wav	street	198.942113	201.510962	children	mixture	b008
# audio/street/b008.wav	street	203.653121	204.410714	people speaking	mixture	b008
# audio/street/b009.wav	street	2.509522	17.005812	car	mixture	b009
# audio/street/b009.wav	street	14.74344	42.005971	car	mixture	b009
# audio/street/b009.wav	street	34.933682	48.992707	car	mixture	b009
# audio/street/b009.wav	street	45.817782	56.99656	car	mixture	b009
# audio/street/b009.wav	street	52.985128	66.987118	car	mixture	b009
# audio/street/b009.wav	street	64.144895	74.030889	car	mixture	b009
# audio/street/b009.wav	street	71.854069	84.030953	car	mixture	b009
# audio/street/b009.wav	street	95.418858	109.487389	car	mixture	b009
# audio/street/b009.wav	street	106.958856	115.019743	car	mixture	b009
# audio/street/b009.wav	street	112.595774	120.998869	car	mixture	b009
# audio/street/b009.wav	street	118.14714	143.508518	large vehicle	mixture	b009
# audio/street/b009.wav	street	139.402028	153.993375	large vehicle	mixture	b009
# audio/street/b009.wav	street	149.535172	150.99906	people walking	mixture	b009
# audio/street/b009.wav	street	152.919224	164.021956	large vehicle	mixture	b009
# audio/street/b009.wav	street	175.447885	195.999346	car	mixture	b009
# audio/street/b009.wav	street	191.854833	203.518405	car	mixture	b009
# audio/street/b009.wav	street	204.297878	224.98242	car	mixture	b009
# audio/street/b009.wav	street	221.807495	227.368367	people walking	mixture	b009
# audio/street/b009.wav	street	229.488152	232.396916	people walking	mixture	b009
# audio/street/b091.wav	street	0.0	5.532196	car	mixture	b091
# audio/street/b091.wav	street	17.477385	27.472945	car	mixture	b091
# audio/street/b091.wav	street	27.472945	30.808097	car	mixture	b091
# audio/street/b091.wav	street	32.896278	38.55713	car	mixture	b091
# audio/street/b091.wav	street	38.55713	46.395232	car	mixture	b091
# audio/street/b091.wav	street	48.503207	51.511771	car	mixture	b091
# audio/street/b091.wav	street	52.263912	54.569819	car	mixture	b091
# audio/street/b091.wav	street	55.856376	59.013389	car	mixture	b091
# audio/street/b091.wav	street	59.013389	61.71516	car	mixture	b091
# audio/street/b091.wav	street	61.71516	63.654892	car	mixture	b091
# audio/street/b091.wav	street	63.654892	66.237903	car	mixture	b091
# audio/street/b091.wav	street	66.831699	69.117812	car	mixture	b091
# audio/street/b091.wav	street	70.622094	77.005397	car	mixture	b091
# audio/street/b091.wav	street	78.074229	81.686486	car	mixture	b091
# audio/street/b091.wav	street	82.636559	86.100367	car	mixture	b091
# audio/street/b091.wav	street	87.02075	90.286626	car	mixture	b091
# audio/street/b091.wav	street	90.989284	92.562843	car	mixture	b091
# audio/street/b091.wav	street	92.562843	95.15575	car	mixture	b091
# audio/street/b091.wav	street	95.413062	106.665489	car	mixture	b091
# audio/street/b091.wav	street	107.932253	112.811274	car	mixture	b091
# audio/street/b091.wav	street	120.975964	125.092947	car	mixture	b091
# audio/street/b091.wav	street	128.170787	130.872558	car	mixture	b091
# audio/street/b091.wav	street	130.872558	140.996773	car	mixture	b091
# audio/street/b091.wav	street	140.996773	144.9851	car	mixture	b091
# audio/street/b091.wav	street	145.954967	150.07195	car	mixture	b091
# audio/street/b091.wav	street	151.239748	155.020247	car	mixture	b091
# audio/street/b091.wav	street	155.020247	160.027923	car	mixture	b091
# audio/street/b091.wav	street	161.215514	164.085527	car	mixture	b091
# audio/street/b091.wav	street	165.9065	173.60605	car	mixture	b091
# audio/street/b091.wav	street	201.257133	235.469658	car	mixture	b091
# audio/street/b091.wav	street	238.092256	241.951927	car	mixture	b091
# audio/street/b093.wav	street	3.794935	110.64771	people walking	mixture	b093
# audio/street/b093.wav	street	11.619621	12.386133	children	mixture	b093
# audio/street/b093.wav	street	14.415647	16.000932	people speaking	mixture	b093
# audio/street/b093.wav	street	16.375478	17.986895	people speaking	mixture	b093
# audio/street/b093.wav	street	21.427487	27.873154	children	mixture	b093
# audio/street/b093.wav	street	22.821145	23.300214	people speaking	mixture	b093
# audio/street/b093.wav	street	25.347149	34.07493	people speaking	mixture	b093
# audio/street/b093.wav	street	32.890321	40.024107	car	mixture	b093
# audio/street/b093.wav	street	38.674001	50.520091	car	mixture	b093
# audio/street/b093.wav	street	50.041021	52.044404	people speaking	mixture	b093
# audio/street/b093.wav	street	51.034002	57.523221	car	mixture	b093
# audio/street/b093.wav	street	60.719923	64.047281	people speaking	mixture	b093
# audio/street/b093.wav	street	63.202376	65.379966	car	mixture	b093
# audio/street/b093.wav	street	65.423518	84.838912	people speaking	mixture	b093
# audio/street/b093.wav	street	66.372947	67.792736	car	mixture	b093
# audio/street/b093.wav	street	79.072653	89.14183	car	mixture	b093
# audio/street/b093.wav	street	92.948257	95.709442	car	mixture	b093
# audio/street/b093.wav	street	95.552655	96.815657	people speaking	mixture	b093
# audio/street/b093.wav	street	97.799928	109.698281	car	mixture	b093
# audio/street/b093.wav	street	101.963481	102.477392	people speaking	mixture	b093
# audio/street/b093.wav	street	106.379633	107.006779	people speaking	mixture	b093
# audio/street/b093.wav	street	109.288894	112.468175	people speaking	mixture	b093
# audio/street/b093.wav	street	110.011854	121.587923	car	mixture	b093
# audio/street/b093.wav	street	118.844159	210.860408	people walking	mixture	b093
# audio/street/b093.wav	street	120.838832	128.53008	car	mixture	b093
# audio/street/b093.wav	street	126.84027	134.57507	car	mixture	b093
# audio/street/b093.wav	street	127.101581	135.341582	people speaking	mixture	b093
# audio/street/b093.wav	street	134.57507	158.014651	car	mixture	b093
# audio/street/b093.wav	street	136.369405	137.4582	brakes squeaking	mixture	b093
# audio/street/b093.wav	street	136.761371	148.320019	people speaking	mixture	b093
# audio/street/b093.wav	street	142.928306	149.600442	car	mixture	b093
# audio/street/b093.wav	street	151.551563	152.69262	people speaking	mixture	b093
# audio/street/b093.wav	street	157.962389	165.00907	car	mixture	b093
# audio/street/b093.wav	street	159.713171	161.315877	people speaking	mixture	b093
# audio/street/b093.wav	street	165.00907	176.045097	car	mixture	b093
# audio/street/b093.wav	street	170.757908	172.918078	people speaking	mixture	b093
# audio/street/b093.wav	street	173.797824	174.459811	people speaking	mixture	b093
# audio/street/b093.wav	street	176.445774	188.030553	car	mixture	b093
# audio/street/b093.wav	street	185.957487	189.241293	people speaking	mixture	b093
# audio/street/b093.wav	street	191.375332	192.79512	people speaking	mixture	b093
# audio/street/b093.wav	street	193.805522	204.815418	car	mixture	b093
# audio/street/b093.wav	street	205.712585	210.860408	car	mixture	b093
# audio/street/b093.wav	street	206.000027	210.860408	people speaking	mixture	b093
# audio/street/b094.wav	street	1.505533	3.493229	car	mixture	b094
# audio/street/b094.wav	street	7.350542	8.816714	car	mixture	b094
# audio/street/b094.wav	street	10.174645	10.784731	children	mixture	b094
# audio/street/b094.wav	street	12.152502	13.195551	people speaking	mixture	b094
# audio/street/b094.wav	street	12.555945	16.580539	car	mixture	b094
# audio/street/b094.wav	street	15.232448	20.004888	people walking	mixture	b094
# audio/street/b094.wav	street	16.816701	17.702309	people speaking	mixture	b094
# audio/street/b094.wav	street	18.322234	19.306242	children	mixture	b094
# audio/street/b094.wav	street	21.42186	22.691231	people speaking	mixture	b094
# audio/street/b094.wav	street	22.150026	29.520248	people walking	mixture	b094
# audio/street/b094.wav	street	25.426774	29.520248	people speaking	mixture	b094
# audio/street/b094.wav	street	32.501793	40.560821	car	mixture	b094
# audio/street/b094.wav	street	40.255778	42.509157	car	mixture	b094
# audio/street/b094.wav	street	42.322195	44.546054	car	mixture	b094
# audio/street/b094.wav	street	44.181971	46.986395	car	mixture	b094
# audio/street/b094.wav	street	47.63584	52.546041	people walking	mixture	b094
# audio/street/b094.wav	street	48.600168	54.317256	large vehicle	mixture	b094
# audio/street/b094.wav	street	53.047885	57.534963	people walking	mixture	b094
# audio/street/b094.wav	street	53.756371	58.145048	people speaking	mixture	b094
# audio/street/b094.wav	street	57.702245	60.585389	car	mixture	b094
# audio/street/b094.wav	street	62.848608	72.541089	car	mixture	b094
# audio/street/b094.wav	street	72.747731	75.601355	people speaking	mixture	b094
# audio/street/b094.wav	street	76.732964	87.084731	people walking	mixture	b094
# audio/street/b094.wav	street	80.688678	87.025691	car	mixture	b094
# audio/street/b094.wav	street	87.084731	107.030579	large vehicle	mixture	b094
# audio/street/b094.wav	street	108.644352	122.499189	large vehicle	mixture	b094
# audio/street/b094.wav	street	116.782101	120.541012	brakes squeaking	mixture	b094
# audio/street/b094.wav	street	120.698454	128.009635	car	mixture	b094
# audio/street/b094.wav	street	127.537311	128.885402	people speaking	mixture	b094
# audio/street/b094.wav	street	129.997332	136.019462	people walking	mixture	b094
# audio/street/b094.wav	street	136.019462	141.008384	car	mixture	b094
# audio/street/b094.wav	street	140.703342	144.540974	car	mixture	b094
# audio/street/b094.wav	street	146.676272	153.013285	large vehicle	mixture	b094
# audio/street/b094.wav	street	152.688562	163.040329	large vehicle	mixture	b094
# audio/street/b094.wav	street	164.132578	164.654103	brakes squeaking	mixture	b094
# audio/street/b094.wav	street	164.545862	171.069837	car	mixture	b094
# audio/street/b094.wav	street	173.047693	177.013246	car	mixture	b094
# audio/street/b094.wav	street	181.697126	187.286293	car	mixture	b094
# audio/street/b094.wav	street	183.330579	184.57043	people speaking	mixture	b094
# audio/street/b094.wav	street	187.591335	192.531057	car	mixture	b094
# audio/street/b094.wav	street	194.184191	200.540884	car	mixture	b094
# audio/street/b094.wav	street	200.649125	206.02181	car	mixture	b094
# audio/street/b094.wav	street	206.02181	209.249357	people speaking	mixture	b094
# audio/street/b094.wav	street	206.503974	207.537183	children	mixture	b094
# audio/street/b094.wav	street	206.592535	210.036564	people walking	mixture	b094
# audio/street/b094.wav	street	209.859442	219.050079	people speaking	mixture	b094
# audio/street/b094.wav	street	212.781947	224.550686	people walking	mixture	b094
# audio/street/b094.wav	street	222.435068	223.546997	people speaking	mixture	b094
# audio/street/b094.wav	street	224.944289	232.019308	car	mixture	b094
# audio/street/b094.wav	street	232.471952	240.57034	car	mixture	b094
# audio/street/b095.wav	street	0.0	2.462242	car	mixture	b095
# audio/street/b095.wav	street	1.720603	4.528943	car	mixture	b095
# audio/street/b095.wav	street	4.044405	6.08144	car	mixture	b095
# audio/street/b095.wav	street	5.755119	8.039367	car	mixture	b095
# audio/street/b095.wav	street	8.504128	12.024441	car	mixture	b095
# audio/street/b095.wav	street	11.50035	14.031811	car	mixture	b095
# audio/street/b095.wav	street	14.971221	18.046551	car	mixture	b095
# audio/street/b095.wav	street	20.251691	22.713932	people walking	mixture	b095
# audio/street/b095.wav	street	24.909184	29.517235	car	mixture	b095
# audio/street/b095.wav	street	35.608564	41.037362	car	mixture	b095
# audio/street/b095.wav	street	40.463827	51.529082	large vehicle	mixture	b095
# audio/street/b095.wav	street	50.856663	55.059284	car	mixture	b095
# audio/street/b095.wav	street	55.059284	60.517748	car	mixture	b095
# audio/street/b095.wav	street	59.30146	66.015765	car	mixture	b095
# audio/street/b095.wav	street	66.45086	69.911842	car	mixture	b095
# audio/street/b095.wav	street	70.435934	78.059984	car	mixture	b095
# audio/street/b095.wav	street	82.104389	96.027426	car	mixture	b095
# audio/street/b095.wav	street	98.835766	102.979056	car	mixture	b095
# audio/street/b095.wav	street	101.584775	112.472036	car	mixture	b095
# audio/street/b095.wav	street	113.154344	120.560846	car	mixture	b095
# audio/street/b095.wav	street	120.976164	121.569475	people speaking	mixture	b095
# audio/street/b095.wav	street	123.537291	132.021642	people speaking	mixture	b095
# audio/street/b095.wav	street	126.246746	130.676803	car	mixture	b095
# audio/street/b095.wav	street	127.116936	135.37385	people walking	mixture	b095
# audio/street/b095.wav	street	132.990717	140.070898	car	mixture	b095
# audio/street/b095.wav	street	136.11549	144.382293	people walking	mixture	b095
# audio/street/b095.wav	street	139.695134	149.010121	car	mixture	b095
# audio/street/b095.wav	street	148.149819	154.508138	people walking	mixture	b095
# audio/street/b095.wav	street	153.351181	159.027192	car	mixture	b095
# audio/street/b095.wav	street	158.334996	164.060449	car	mixture	b095
# audio/street/b095.wav	street	163.279256	167.293996	car	mixture	b095
# audio/street/b095.wav	street	167.501655	169.993562	car	mixture	b095
# audio/street/b095.wav	street	168.955267	173.82042	car	mixture	b095
# audio/street/b095.wav	street	173.207331	176.312327	car	mixture	b095
# audio/street/b095.wav	street	175.976117	178.517467	car	mixture	b095
# audio/street/b095.wav	street	178.448247	182.522318	car	mixture	b095
# audio/street/b095.wav	street	181.90923	185.034002	car	mixture	b095
# audio/street/b095.wav	street	185.439432	188.030224	car	mixture	b095
# audio/street/b095.wav	street	187.446801	190.522131	car	mixture	b095
# audio/street/b095.wav	street	190.007928	194.002891	car	mixture	b095
# audio/street/b095.wav	street	193.923782	198.55161	car	mixture	b095
# audio/street/b095.wav	street	198.55161	214.027145	car	mixture	b095
# audio/street/b095.wav	street	218.536311	224.4892	car	mixture	b095
# audio/street/b095.wav	street	223.935443	226.793226	car	mixture	b095
# audio/street/b095.wav	street	226.021921	229.067586	car	mixture	b095
# audio/street/b095.wav	street	228.642379	230.877185	people walking	mixture	b095
# audio/street/b095.wav	street	233.537197	241.754558	car	mixture	b095
# audio/street/b098.wav	street	4.753563	11.544367	car	mixture	b098
# audio/street/b098.wav	street	10.343674	11.436107	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	14.280372	15.205496	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	15.746792	22.50807	car	mixture	b098
# audio/street/b098.wav	street	24.240217	25.135816	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	25.480277	26.90733	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	26.434926	29.072514	car	mixture	b098
# audio/street/b098.wav	street	30.046847	35.499173	car	mixture	b098
# audio/street/b098.wav	street	32.930478	33.580033	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	34.081962	40.046059	car	mixture	b098
# audio/street/b098.wav	street	37.979293	47.515944	car	mixture	b098
# audio/street/b098.wav	street	48.942997	54.729942	car	mixture	b098
# audio/street/b098.wav	street	53.106055	56.196362	car	mixture	b098
# audio/street/b098.wav	street	56.12747	60.536572	car	mixture	b098
# audio/street/b098.wav	street	60.408629	73.517833	car	mixture	b098
# audio/street/b098.wav	street	71.165656	72.356507	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	73.517833	74.561058	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	74.905519	82.513188	car	mixture	b098
# audio/street/b098.wav	street	87.060074	121.486497	car	mixture	b098
# audio/street/b098.wav	street	107.481694	117.067554	car	mixture	b098
# audio/street/b098.wav	street	114.557909	122.588772	people walking	mixture	b098
# audio/street/b098.wav	street	117.697425	118.425714	people speaking	mixture	b098
# audio/street/b098.wav	street	119.567357	120.029919	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	121.112511	132.056531	car	mixture	b098
# audio/street/b098.wav	street	125.433037	127.342335	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	128.907172	129.389418	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	131.052673	133.985513	car	mixture	b098
# audio/street/b098.wav	street	133.818203	140.500748	car	mixture	b098
# audio/street/b098.wav	street	142.154161	149.535469	car	mixture	b098
# audio/street/b098.wav	street	147.911581	148.600504	people walking	mixture	b098
# audio/street/b098.wav	street	149.535469	155.489725	car	mixture	b098
# audio/street/b098.wav	street	152.852137	156.513266	people walking	mixture	b098
# audio/street/b098.wav	street	154.84017	164.54413	car	mixture	b098
# audio/street/b098.wav	street	162.260845	167.565546	car	mixture	b098
# audio/street/b098.wav	street	166.315644	166.79789	brakes squeaking	mixture	b098
# audio/street/b098.wav	street	167.221085	173.982363	car	mixture	b098
# audio/street/b098.wav	street	193.774112	204.324462	people walking	mixture	b098
# audio/street/b098.wav	street	198.38989	205.525155	car	mixture	b098
# audio/street/b098.wav	street	204.08826	209.058341	car	mixture	b098
# audio/street/b098.wav	street	206.578222	214.057948	car	mixture	b098
# audio/street/b098.wav	street	213.231241	216.282182	people walking	mixture	b098
# audio/street/b098.wav	street	215.347216	221.045587	car	mixture	b098
# audio/street/b098.wav	street	218.860719	224.470514	car	mixture	b098
# audio/street/b098.wav	street	222.738367	226.045193	car	mixture	b098
# audio/street/b098.wav	street	225.159436	232.993465	car	mixture	b098
# audio/street/b099.wav	street	0.186989	2.558792	car	mixture	b099
# audio/street/b099.wav	street	2.421011	4.536935	car	mixture	b099
# audio/street/b099.wav	street	4.271214	10.530413	car	mixture	b099
# audio/street/b099.wav	street	11.475197	13.51239	car	mixture	b099
# audio/street/b099.wav	street	13.837159	22.064659	car	mixture	b099
# audio/street/b099.wav	street	15.500374	18.187105	brakes squeaking	mixture	b099
# audio/street/b099.wav	street	18.531558	22.00561	car	mixture	b099
# audio/street/b099.wav	street	27.48733	38.047267	car	mixture	b099
# audio/street/b099.wav	street	38.214573	46.009047	car	mixture	b099
# audio/street/b099.wav	street	46.156669	50.034223	car	mixture	b099
# audio/street/b099.wav	street	59.344289	66.695895	car	mixture	b099
# audio/street/b099.wav	street	66.961616	69.559773	car	mixture	b099
# audio/street/b099.wav	street	76.537402	99.044929	car	mixture	b099
# audio/street/b099.wav	street	108.138482	137.495698	large vehicle	mixture	b099
# audio/street/b099.wav	street	143.105357	149.029945	car	mixture	b099
# audio/street/b099.wav	street	153.448782	162.51281	car	mixture	b099
# audio/street/b099.wav	street	157.247603	162.798213	brakes squeaking	mixture	b099
# audio/street/b099.wav	street	162.650591	168.073261	car	mixture	b099
# audio/street/b099.wav	street	167.394197	171.025714	car	mixture	b099
# audio/street/b099.wav	street	173.249894	176.054724	car	mixture	b099
# audio/street/b099.wav	street	176.310603	182.048202	car	mixture	b099
# audio/street/b099.wav	street	180.001168	185.994646	car	mixture	b099
# audio/street/b099.wav	street	186.959114	223.10697	car	mixture	b099
# audio/street/b099.wav	street	220.075786	228.539482	car	mixture	b099
# audio/street/b099.wav	street	224.691453	224.691453	car	mixture	b099
# audio/street/b099.wav	street	225.675604	232.033217	car	mixture	b099
# audio/street/b099.wav	street	232.623708	240.60517	car	mixture	b099
# audio/street/b100.wav	street	0.0	1.519946	people speaking	mixture	b100
# audio/street/b100.wav	street	5.642337	10.817569	people speaking	mixture	b100
# audio/street/b100.wav	street	8.511699	21.67221	car	mixture	b100
# audio/street/b100.wav	street	13.212412	20.463668	people speaking	mixture	b100
# audio/street/b100.wav	street	19.944662	33.527792	large vehicle	mixture	b100
# audio/street/b100.wav	street	21.049403	33.527792	brakes squeaking	mixture	b100
# audio/street/b100.wav	street	30.391512	43.010774	large vehicle	mixture	b100
# audio/street/b100.wav	street	36.234038	41.535314	people walking	mixture	b100
# audio/street/b100.wav	street	40.467644	42.069149	people speaking	mixture	b100
# audio/street/b100.wav	street	44.723494	49.513179	people walking	mixture	b100
# audio/street/b100.wav	street	45.531661	49.787511	people speaking	mixture	b100
# audio/street/b100.wav	street	46.873662	48.527067	car	mixture	b100
# audio/street/b100.wav	street	48.816228	64.008277	car	mixture	b100
# audio/street/b100.wav	street	59.270493	62.013811	people walking	mixture	b100
# audio/street/b100.wav	street	59.715355	79.000138	people speaking	mixture	b100
# audio/street/b100.wav	street	66.45502	76.01956	car	mixture	b100
# audio/street/b100.wav	street	68.582945	71.533865	people walking	mixture	b100
# audio/street/b100.wav	street	74.922233	88.535021	people walking	mixture	b100
# audio/street/b100.wav	street	79.000138	97.017063	car	mixture	b100
# audio/street/b100.wav	street	81.847257	84.946464	people speaking	mixture	b100
# audio/street/b100.wav	street	99.715894	113.499212	people speaking	mixture	b100
# audio/street/b100.wav	street	102.318339	111.007983	people walking	mixture	b100
# audio/street/b100.wav	street	107.063537	132.005486	large vehicle	mixture	b100
# audio/street/b100.wav	street	119.630898	125.028561	large vehicle	mixture	b100
# audio/street/b100.wav	street	121.039629	131.493894	people speaking	mixture	b100
# audio/street/b100.wav	street	124.761644	180.413923	people walking	mixture	b100
# audio/street/b100.wav	street	133.784935	136.009247	children	mixture	b100
# audio/street/b100.wav	street	135.74233	137.729381	people speaking	mixture	b100
# audio/street/b100.wav	street	140.865661	150.037239	people speaking	mixture	b100
# audio/street/b100.wav	street	143.71278	168.017093	large vehicle	mixture	b100
# audio/street/b100.wav	street	151.20871	163.50174	people speaking	mixture	b100
# audio/street/b100.wav	street	153.129033	153.677696	brakes squeaking	mixture	b100
# audio/street/b100.wav	street	164.517509	172.006025	car	mixture	b100
# audio/street/b100.wav	street	171.783594	180.413923	people speaking	mixture	b100

# %% [markdown]
# ### 🎶 **Merging Audio Files for Easier Access**
#
# To simplify the process of accessing the audio files from the **TUT-SED 2017** dataset, we will merge the audio files from both parts (audio1 and audio2) into a single directory. This will make it easier to load and process all audio files in one place.
#
# Here are the steps:
#
# 1. **Create a New Directory**: We create a new folder, `audio_merged`, where all the audio files will be consolidated.
# 2. **Move Audio Files**:
#    - First, we move all audio files from **audio1** to the new `audio_merged` directory.
#    - Then, we move the remaining files from **audio2** to the same `audio_merged` folder.
#
# This step ensures that all audio files are organized in one place, facilitating seamless data loading and processing.

# %%
# Create a new directory for merged audio files
# !mkdir /content/dataset/audio_merged
# Move all files from audio1 to audio_merged
# !mv /content/dataset/audio1/TUT-sound-events-2017-development/audio/street/* /content/dataset/audio_merged/
# Move all files from audio2 to audio_merged
# !mv /content/dataset/audio2/TUT-sound-events-2017-development/audio/street/* /content/dataset/audio_merged/

# %%
# List the contents of the audio_merged folder
# !ls /content/dataset/audio_merged
# Count the number of files in the audio_merged folder
# !ls /content/dataset/audio_merged | wc -l
# Out:
# a001.wav  a010.wav  a124.wav  a129.wav	b005.wav  b008.wav  b093.wav  b098.wav
# a003.wav  a012.wav  a127.wav  a131.wav	b006.wav  b009.wav  b094.wav  b099.wav
# a008.wav  a013.wav  a128.wav  b003.wav	b007.wav  b091.wav  b095.wav  b100.wav

# %%
# Delete the audio1 and audio2 folders
# !rm -r /content/dataset/audio1
# !rm -r /content/dataset/audio2

# %% [markdown]
# ### 🔄 **Loading and Preparing the Audio and Metadata**
#
# Now, we need to load and organize both the audio files and the metadata for the TUT-SED 2017 dataset. Here's what we do:
#
# 1. **Retrieve Audio Files**: We use the `glob` library to gather all `.wav` audio files from the `audio_merged` folder. These files will be used for sound event detection.
#
# 2. **Load Annotations**: We load the metadata file (`meta.txt`), which contains important information like:
#    - The path to the audio file.
#    - The scene where the sound was recorded.
#    - The onset and offset times of sound events.
#    - The type of sound event (e.g., footsteps, speech, etc.).
#
#    To make the data more readable, we define clear headers for each column. We also drop any unnecessary columns, like `Extra 1` and `Extra 2`.
#
# This prepares both the audio and metadata for further processing.

# %%
# Define headers for the columns in the sound event annotation file
# These columns correspond to the audio file path, scene label, onset time, offset time, and event label.
header = ["Audio file path", "Scene", "Onset", "Offset", "Event label", "Extra 1", "Extra 2"]

# Step 1: Retrieve all audio files from the merged audio directory using glob
# This step collects all .wav files from the specified directory, where the merged audio files are stored
audio_files = glob.glob('/content/dataset/audio_merged/*.wav')

# Step 2: Load the sound event annotations from the 'meta.txt' file located in the metadata folder
# The file is tab-delimited and contains information about sound events (e.g., start time, end time, and event label)
# Headers are added to improve interpretability of the loaded data
annotations = pd.read_csv('/content/dataset/meta/TUT-sound-events-2017-development/meta.txt', delimiter='\t', header=None, names=header)

# Remove unnecessary columns ('Extra 1' and 'Extra 2') from the annotations dataframe
annotations = annotations.drop(columns=['Extra 1', 'Extra 2'])

# %%
# Print the list of audio file paths
print("Audio Files:")
for audio_file in audio_files:
    print(audio_file)

# Print the first few rows of the annotations dataframe to see the loaded data
print("\nAnnotations:")
print(annotations.head())

# %%
# Save the DataFrame to a CSV file for future use
annotations.to_csv('processed_metadata.csv', index=False)
print("DataFrame has been saved to 'processed_data.csv'")
# Out:
# DataFrame has been saved to 'processed_data.csv'

# %% [markdown]
# ### 🛃 **CustomDataset Class**
#
# The `CustomDataset` class is designed to facilitate working with audio data in PyTorch. It handles loading audio files and their corresponding labels, making it easier to integrate custom datasets into PyTorch's data loading pipeline.
#
# - **Initialization (`__init__` method):**
#   The class is initialized with:
#   - The path to the directory containing audio files.
#   - A CSV file containing labels for each audio file.
#   - An optional transformation function to be applied to the audio data.
#
# - **Dataset Length (`__len__` method):**
#   This method returns the total number of samples in the dataset, which corresponds to the number of rows in the labels CSV file.
#
# - **Fetching Items (`__getitem__` method):**
#   Given an index, this method:
#   - Retrieves the file path of the audio sample.
#   - Loads the audio file using `torchaudio`.
#   - Extracts the corresponding label from the labels DataFrame.
#   - Returns a tuple containing the audio signal and its label.
#
# - **Audio Path Retrieval (`get_audio_path` method):**
#   Constructs and returns the full file path to an audio sample based on its index and the base directory where audio files are stored.
#
# - **Label Retrieval (`get_audio_label` method):**
#   Extracts and returns the label for a given audio sample based on its index in the labels DataFrame.
#
# This class provides a structured way to manage and preprocess audio data for machine learning tasks using PyTorch.

# %%
class CustomDataset(Dataset):
    def __init__(self, data, labels, transform=None):
        """
        Initializes the CustomDataset.

        Parameters:
        - data (str): Directory path where audio files are stored.
        - labels (str): Path to the CSV file containing labels for the audio files.
        - transform (callable, optional): Optional transformation function to apply to the audio data.
        """
        self.data = data
        self.labels = pd.read_csv(labels)  # Load labels from the CSV file into a DataFrame
        self.transform = transform

    def __len__(self):
        """
        Returns the total number of samples in the dataset.

        Returns:
        - int: Number of samples, which is the length of the labels DataFrame.
        """
        return len(self.labels)

    def __getitem__(self, idx):
        """
        Retrieves an audio sample and its label based on the index.

        Parameters:
        - idx (int): Index of the sample to retrieve.

        Returns:
        - tuple: (signal, label) where `signal` is the loaded audio signal and `label` is the corresponding label.
        """
        audio_path = self.get_audio_path(idx)  # Get the file path for the audio sample
        label = self.get_audio_label(idx)      # Get the label for the audio sample
        signal, sr = torchaudio.load(audio_path)  # Load the audio file
        return signal, label

    def get_audio_path(self, idx):
        """
        Constructs the file path for an audio sample based on its index.

        Parameters:
        - idx (int): Index of the sample.

        Returns:
        - str: Full path to the audio file.
        """
        file_path = self.labels.iloc[idx, 0]  # Extract file path from the labels DataFrame
        file_name = file_path.split('/')[-1]
        path = os.path.join(self.data, file_name)  # Join directory path with filename from labels DataFrame
        return path

    def get_audio_label(self, idx):
        """
        Retrieves the label for a given audio sample based on its index.

        Parameters:
        - idx (int): Index of the sample.

        Returns:
        - str: Label for the audio sample.
        """
        label = self.labels.iloc[idx, 4]  # Extract label from the labels DataFrame at position 4
        return label

# %% [markdown]
# ## 🧰 **Dataset usage**
#
# In this section, we perform the following steps:
#
# 1. **Define Paths:**
#    - Specify the directory where the audio files are stored.
#    - Provide the path to the CSV file containing the annotations (labels) for these audio files.
#
# 2. **Initialize the Dataset:**
#    - Create an instance of the `CustomDataset` class using the defined paths for audio data and annotations.
#
# 3. **Print Dataset Size:**
#    - Output the total number of samples in the dataset. This helps verify that the dataset is loaded correctly and provides insight into its size.
#
# This process ensures that the dataset is properly set up and gives a clear understanding of the amount of data available for analysis or model training.

# %%
# Define the path to the directory containing audio files
audio_data_path = '/content/dataset/audio_merged'

# Define the path to the CSV file containing annotations (labels) for the audio files
annotations_path = '/content/dataset/meta/TUT-sound-events-2017-development/processed_metadata.csv'

# Create an instance of the CustomDataset class with the specified paths
tutsed2017dataset = CustomDataset(audio_data_path, annotations_path)

# Print the total number of samples in the dataset
print(f"There are {len(tutsed2017dataset)} samples in the dataset")
# Out:
# There are 729 samples in the dataset

# %% [markdown]
# ## ⌨ **Accessing and Inspecting a Dataset Sample**
#
# In this section, we perform the following steps to inspect a sample from the dataset:
#
# 1. **Retrieve a Sample:**
#    - We access the first sample from the dataset using `ICBHI[0]`. This retrieves a tuple consisting of the audio signal and its corresponding label.
#
# 2. **Inspect Signal and Label:**
#    - We then print the shape of the audio signal and the label associated with this sample. This helps us understand the structure of the audio data (e.g., its dimensions) and verify the label information.
#
# By examining a sample, we gain insights into the format of the audio data and the type of labels provided, which is crucial for ensuring data consistency and preparing for further analysis or model training.

# %%
# Retrieve the first sample from the dataset
signal, label = tutsed2017dataset[1]

# Print the shape of the audio signal and the corresponding label
signal, label
# Out:
# (tensor([[0.0209, 0.0215, 0.0217,  ..., 0.0013, 0.0012, 0.0012],
#          [0.0140, 0.0145, 0.0147,  ..., 0.0019, 0.0022, 0.0024]]),
#  'people walking')

# %% [markdown]
# ## 👏 **Conclusion**
# By completing these steps, we’ve established a solid foundation for working with the TUTSED sound dataset. This preparation is crucial for subsequent stages such as data preprocessing, feature extraction, and model training. With the dataset correctly set up and verified, we can now proceed to further analysis and experimentation to advance our research or project objectives. Feel free to build on this setup with additional analysis, feature extraction, or model training as needed.
